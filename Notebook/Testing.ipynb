# %%
import pandas as pd

# %%
df=pd.read_csv("/config/workspace/prediction/mushrooms12262022__200721.csv")

# %%
df
# Out:
#      class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0        p          5            2          4        1     6                1
# 1        e          5            2          9        1     0                1
# 2        e          0            2          8        1     3                1
# 3        p          5            3          8        1     6                1
# 4        e          5            2          3        0     5                1
# ...    ...        ...          ...        ...      ...   ...              ...
# 8119     e          3            2          4        0     5                0
# 8120     e          5            2          4        0     5                0
# 8121     e          2            2          4        0     5                0
# 8122     p          3            3          4        0     8                1
# 8123     e          5            2          4        0     5                0
#
# ...

# %%
 df.replace({"1.0":"Poisonous","0.0":"Edible"},inplace=True)

# %%
df
# Out:
#      class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0        p          5            2          4        1     6                1
# 1        e          5            2          9        1     0                1
# 2        e          0            2          8        1     3                1
# 3        p          5            3          8        1     6                1
# 4        e          5            2          3        0     5                1
# ...    ...        ...          ...        ...      ...   ...              ...
# 8119     e          3            2          4        0     5                0
# 8120     e          5            2          4        0     5                0
# 8121     e          2            2          4        0     5                0
# 8122     p          3            3          4        0     8                1
# 8123     e          5            2          4        0     5                0
#
# ...

# %%
df["prediction"].replace({1.0:"Poisonous",0.0:"Edible"},inplace=True)

# %%
df["prediction"]
# Out:
# 0       Poisonous
# 1          Edible
# 2          Edible
# 3       Poisonous
# 4          Edible
#           ...
# 8119       Edible
# 8120       Edible
# 8121       Edible
# 8122    Poisonous
# 8123       Edible
# Name: prediction, Length: 8124, dtype: object
